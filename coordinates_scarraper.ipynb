# %% [markdown]
# <a href="https://colab.research.google.com/github/rajnish80130/Campusx-session-28-data-accessing-and-cleaning/blob/main/coordinates_scarraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import time

# %%
API_KEY = 'eabd44fdfb3143b9804eaa0cad692354'

# %%
def get_coordinates(sector):
    query = f"Sector {sector}, Gurgaon, India"
    url = f"https://api.opencagedata.com/geocode/v1/json?q={query}&key={API_KEY}"

    response = requests.get(url)
    data = response.json()

    if data['results']:
        geometry = data['results'][0]['geometry']
        return geometry['lat'], geometry['lng']
    return None, None

# %%
# DataFrame
sectors = list(range(1, 116))
data = []

# %%
for sector in sectors:
    lat, lng = get_coordinates(sector)
    data.append({'Sector': f'Sector {sector}', 'Latitude': lat, 'Longitude': lng})
    time.sleep(1)  # Respect rate limits

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#      Sector   Latitude  Longitude
# 0  Sector 1  28.518781  77.041862
# 1  Sector 2  28.509050  77.034283
# 2  Sector 3  28.362766  76.919326
# 3  Sector 4  28.475006  77.010353
# 4  Sector 5  28.480392  77.019095

# %%
df.rename(columns={'Sector':'sector'}, inplace=True)

# %%
df.head()
# Out:
#      sector   Latitude  Longitude
# 0  Sector 1  28.518781  77.041862
# 1  Sector 2  28.509050  77.034283
# 2  Sector 3  28.362766  76.919326
# 3  Sector 4  28.475006  77.010353
# 4  Sector 5  28.480392  77.019095

# %%
df['sector'] = df['sector'].str.lower()

# %%
df.head()
# Out:
#      sector   Latitude  Longitude
# 0  sector 1  28.518781  77.041862
# 1  sector 2  28.509050  77.034283
# 2  sector 3  28.362766  76.919326
# 3  sector 4  28.475006  77.010353
# 4  sector 5  28.480392  77.019095

# %%
df.shape
# Out:
# (115, 3)

# %%
df.to_csv('gurgaon_sector_coordinates.csv', index=False)
